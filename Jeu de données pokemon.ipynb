# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucreiche04/Lucreiche04/blob/main/Jeu%20de%20donn%C3%A9es%20pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importation de Pandas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Charger le fichier CSV dans un DataFrame
df = pd.read_csv('/content/pokemon.csv')

# Afficher les premières lignes pour vérifier le chargement
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Afficher les 5 premières lignes du dataset
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Obtenir des informations sur les colonnes et leur type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# Les types de données affichés sont :
#
# int64 : Entiers (nombre sans virgule)
# float64 : Nombre à virgule flottante
# object : Chaînes de caractères

# %%
# Afficher les dimensions (nombre de lignes, nombre de colonnes)
df.shape
# Out:
# (800, 12)

# %% [markdown]
# Une variable catégorielle contient un nombre limité de valeurs distinctes (comme Type 1, Legendary).

# %%
# Exemple avec la colonne 'Type 1'pour identifier les variables categorielles
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
# Obtenir des statistiques de base sur les colonnes numériques
df.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000
# ...

# %%
#Analyse univariée
#Visualisation de la distribution des variables numériques.
# 1. Visualiser la distribution de la variable HP
# Création d'une figure avec 3 sous-graphes (1 ligne, 3 colonnes)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))  # 18 de largeur et 5 de hauteur

# 1. Visualiser la distribution de la variable HP
sns.histplot(df['HP'], kde=True, color='blue', ax=axes[0])
axes[0].set_title('Distribution de HP')
axes[0].set_xlabel('HP')
axes[0].set_ylabel('Fréquence')

# 2. Visualiser la distribution de l'attaque
sns.histplot(df['Attack'], kde=True, color='green', ax=axes[1])
axes[1].set_title('Distribution de Attack')
axes[1].set_xlabel('Attack')
axes[1].set_ylabel('Fréquence')

# 3. Visualiser la distribution de la variable Defense
sns.histplot(df['Defense'], kde=True, color='red', ax=axes[2])
axes[2].set_title('Distribution de Defense')
axes[2].set_xlabel('Defense')
axes[2].set_ylabel('Fréquence')

# Ajustement des espaces entre les sous-graphes
plt.tight_layout()

# Affichage de la figure avec les trois sous-graphes
plt.show()

# %% [markdown]
# **Interpretation**
#
# HP: La distribution de HP montre une repartition symétrique de 50 à 80
#
# Attack: La distribution de l'attaque est légèrement décalée vers la droite, ceci indique que la plupart des pokemons ont une attaque modérée entre 50 et 100, avec des valeurs plus élevées
#
# Defense: La distribution de l'attaque est légèrement décalée vers la droite, ceci indique que la plupart des pokemons ont une attaque modérée entre 60 et 80, avec des valeurs plus élevées.

# %%
#Analyse univariée
#Visualisation de la distribution des variables numériques.
# 1. Visualiser la distribution de la variable HP
# Création d'une figure avec 3 sous-graphes (1 ligne, 3 colonnes)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))  # 18 de largeur et 5 de hauteur

# 1. Visualiser la distribution de la variable Sp. Atk
sns.histplot(df['Sp. Atk'], kde=True, color='blue', ax=axes[0])
axes[0].set_title('Distribution de Sp. Atk')
axes[0].set_xlabel('Sp. Atk')
axes[0].set_ylabel('Fréquence')

# 2. Visualiser la distribution de Sp. Def
sns.histplot(df['Sp. Def'], kde=True, color='green', ax=axes[1])
axes[1].set_title('Distribution de Sp. Def')
axes[1].set_xlabel('Sp. Def')
axes[1].set_ylabel('Fréquence')

# 3. Visualiser la distribution de la variable Speed
sns.histplot(df['Speed'], kde=True, color='red', ax=axes[2])
axes[2].set_title('Distribution de Speed')
axes[2].set_xlabel('Speed')
axes[2].set_ylabel('Fréquence')

# Ajustement des espaces entre les sous-graphes
plt.tight_layout()

# Affichage de la figure avec les trois sous-graphes
plt.show()

# %% [markdown]
# Interpretation
#
# Sp. Atk: La distribution de Sp. Atk montre une repartition asymétrique
#
# Sp. Def: La distribution de l'attaque est décalée vers la droite, ceci indique que la plupart des pokemons ont une attaque modérée entre 50 et 100, avec des valeurs plus élevées. Il y a des variables aberrantes entre 150 et 200
#
# Speed: La distribution de l'attaque est légèrement décalée vers la droite, ceci indique que la plupart des pokemons ont une attaque modérée entre 60 et 75, avec des valeurs plus élevées.Il y a des variables aberrantes entre 150 et 175

# %%
#Analyser les variables categorielles

# Création d'une figure avec 4 sous-graphes (1 ligne, 4 colonnes)
fig, axes = plt.subplots(1, 4, figsize=(20, 5))  # Taille ajustée pour 4 graphiques

# 1. Fréquence des types de Pokémon (Type 1)
sns.countplot(x='Type 1', data=df, order=df['Type 1'].value_counts().index, ax=axes[0])
axes[0].set_title('Répartition des Types (Type 1)')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
axes[0].set_xlabel('Type 1')
axes[0].set_ylabel('Fréquence')

# 2. Fréquence par génération
sns.countplot(x='Generation', data=df, ax=axes[1])
axes[1].set_title('Répartition par Génération')
axes[1].set_xlabel('Génération')
axes[1].set_ylabel('Fréquence')

# 3. Fréquence des types de Pokémon (Type 2)
sns.countplot(x='Type 2', data=df, order=df['Type 2'].value_counts().index, ax=axes[2])
axes[2].set_title('Répartition des Types (Type 2)')
axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
axes[2].set_xlabel('Type 2')
axes[2].set_ylabel('Fréquence')

# 4. Fréquence des Pokémon légendaires
sns.countplot(x='Legendary', data=df, ax=axes[3])
axes[3].set_title('Répartition des Pokémon Légendaires')
axes[3].set_xlabel('Legendary')
axes[3].set_ylabel('Fréquence')

# Ajustement des espaces entre les sous-graphes
plt.tight_layout()

# Affichage de la figure avec les quatre sous-graphes
plt.show()
# Out:
# <ipython-input-17-9641ed408688>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# <ipython-input-17-9641ed408688>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)

# %%
# Calcul de la moyenne, médiane et mode pour HP
moyenne_hp = df['HP'].mean()
mediane_hp = df['HP'].median()
mode_hp = df['HP'].mode()[0]  # Le mode peut avoir plusieurs valeurs, on prend la première

print(f"Moyenne HP: {moyenne_hp}, Médiane HP: {mediane_hp}, Mode HP: {mode_hp}")
# Out:
# Moyenne HP: 69.25875, Médiane HP: 65.0, Mode HP: 60

# %%
# Calcul de la moyenne, médiane et mode pour Attack
moyenne_Attack = df['Attack'].mean()
mediane_Attack = df['Attack'].median()
mode_Attack = df['Attack'].mode()[0]  # Le mode peut avoir plusieurs valeurs, on prend la première

print(f"Moyenne Attack: {moyenne_Attack}, Médiane Attack: {mediane_Attack}, Mode Attack: {mode_Attack}")
# Out:
# Moyenne Attack: 79.00125, Médiane Attack: 75.0, Mode Attack: 100

# %%
# Calcul de la moyenne, médiane et mode pour Defense
moyenne_Defense = df['Defense'].mean()
mediane_Defense = df['Defense'].median()
mode_Defense = df['Defense'].mode()[0]  # Le mode peut avoir plusieurs valeurs, on prend la première

print(f"Moyenne Defense: {moyenne_Defense}, Médiane Defense: {mediane_Defense}, Mode Defense: {mode_Defense}")
# Out:
# Moyenne Defense: 73.8425, Médiane Defense: 70.0, Mode Defense: 70

# %%
# Ecart-type et quartiles pour HP
ecart_type_hp = df['HP'].std()
quartiles_hp = df['HP'].quantile([0.25, 0.5, 0.75])

print(f"Ecart-type HP: {ecart_type_hp}")
print(f"Quartiles HP: \n{quartiles_hp}")

# Ecart-type et quartiles pour Attack
ecart_type_Attack = df['Attack'].std()
quartiles_Attack = df['Attack'].quantile([0.25, 0.5, 0.75])

print(f"Ecart-type Attack: {ecart_type_Attack}")
print(f"Quartiles Attack: \n{quartiles_Attack}")

# Ecart-type et quartiles pour Defense
ecart_type_Defense = df['Defense'].std()
quartiles_Defense = df['Defense'].quantile([0.25, 0.5, 0.75])

print(f"Ecart-type Defense: {ecart_type_Defense}")
print(f"Quartiles Defense: \n{quartiles_Defense}")
# Out:
# Ecart-type HP: 25.53466903233207
# Quartiles HP:
# 0.25    50.0
# 0.50    65.0
# 0.75    80.0
# Name: HP, dtype: float64
# Ecart-type Attack: 32.45736586949845
# Quartiles Attack:
# 0.25     55.0
# 0.50     75.0
# 0.75    100.0
# Name: Attack, dtype: float64
# Ecart-type Defense: 31.183500559332934
# Quartiles Defense:
# 0.25    50.0
# 0.50    70.0
# 0.75    90.0
# Name: Defense, dtype: float64

# %% [markdown]
# **Interpretation**
#
# Les moyennes et les médianes sont relativement provhes, ce qui signifie que les distributions ne sont pas fortement biaisées.
#
# L'écart-type est assez élévé pour Attack et Defense

# %%
#Identifier les valeurs aberrantes
#Boîte à moustaches pour HP
plt.figure(figsize=(10, 6))
sns.boxplot(y='HP', data=df)
plt.title('Boîte à moustaches pour HP')
plt.show()

# %%
#Identifier les valeurs aberrantes
#Boîte à moustaches pour Attack
plt.figure(figsize=(10, 6))
sns.boxplot(y='Attack', data=df)
plt.title('Boîte à moustaches pour Attack')
plt.show()

# %%
#Identifier les valeurs aberrantes
#Boîte à moustaches pour Defense
plt.figure(figsize=(10, 6))
sns.boxplot(y='Defense', data=df)
plt.title('Boîte à moustaches pour Defense')
plt.show()

# %%
#Analyse Bivariée
#Visualiser la relation entre deux variables numériques
# Relation entre HP et Attack
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HP', y='Attack', data=df)
plt.title('Relation entre HP et Attack')
plt.show()

# %%
#Analyse Bivariée
#Visualiser la relation entre deux variables numériques
# Relation entre Defense et Special Defense
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Defense', y='Sp. Def', data=df)
plt.title('Relation entre Defense et Sp. Defense')
plt.show()

# %%
#Analyse Bivariée
#Visualiser la relation entre deux variables numériques
# Relation entre Speed et Attack
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Speed', y='Attack', data=df)
plt.title('Relation entre Speed et Attack')
plt.show()

# %%
# Boîte à moustaches pour Attack en fonction de Type 1
plt.figure(figsize=(10, 6))
sns.boxplot(x='Type 1', y='Attack', data=df)
plt.xticks(rotation=90)
plt.title('Attack par Type de Pokémon')
plt.show()

# %%
# Boîte à moustaches pour HP en fonction de la Generation
plt.figure(figsize=(10, 6))
sns.boxplot(x='HP', y='Generation', data=df)
plt.xticks(rotation=90)
plt.title('HP par Generation de Pokémon')
plt.show()

# %%
# Examiner la relation entre deux variables catégorielles
# Créer un tableau croisé entre 'Legendary' et 'Generation'
ct = pd.crosstab(df['Type 1'], df['Type 2'])

# Filtrer les lignes et les colonnes avec toutes les valeurs nulles
ct_filtered = ct.loc[(ct != 0).any(axis=1), (ct != 0).any(axis=0)]

# Créer la heatmap avec Seaborn
plt.figure(figsize=(10, 6))
sns.heatmap(ct_filtered, annot=True, cmap="YlGnBu", fmt="d")
plt.title("Heatmap Type 1 et Type 2 (Seaborn) - Filtré")
plt.show()

# %%
# Examiner la relation entre deux variables catégorielles
# Créer un tableau croisé entre 'Legendary' et 'Generation'
ct = pd.crosstab(df['Legendary'], df['Generation'])

# Filtrer les lignes et les colonnes avec toutes les valeurs nulles
ct_filtered = ct.loc[(ct != 0).any(axis=1), (ct != 0).any(axis=0)]

# Créer la heatmap avec Seaborn
plt.figure(figsize=(10, 6))
sns.heatmap(ct_filtered, annot=True, cmap="YlGnBu", fmt="d")
plt.title("Heatmap Legendary et Generation (Seaborn) - Filtré")
plt.show()

# %%
#Matrice de correlation des statistiques de Pokémon
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matrice de Corrélation des Statistiques des Pokémon')
plt.show()
